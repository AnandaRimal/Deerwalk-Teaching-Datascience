# %%
http://127.0.0.1:8000/add

# %%
# main.py
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware

app = FastAPI()


# Test addition API
@app.post("/add")
def add_numbers(data: dict):
    a = data.get("a", 0)
    b = data.get("b", 0)
    return {"result": a + b}  # Just return the sum

# %%
uvicorn main:app --reload
