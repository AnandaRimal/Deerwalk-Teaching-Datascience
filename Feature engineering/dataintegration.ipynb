# %% [markdown]
# Data Integration
#
# Combining data from multiple sources.
#
# Merging tables or datasets with common keys.
# Example: Combining customer purchase data with customer demographic data.
#
# Resolving Conflicts:
#
# Handle discrepancies in units, formats, or naming conventions.
# Example: “Male” vs “M” in gender column.

# %% [markdown]
# we are already learn in pandas so you can try yourelf
